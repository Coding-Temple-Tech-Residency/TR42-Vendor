# %%
import pandas as pd
import sqlite3
from datetime import datetime, timedelta

# %%
conn = sqlite3.connect("./my_database.db")

# %%
addresses = pd.read_sql_query(
    "select * from address", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
contractors = pd.read_sql_query(
    "select * from contractors", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
invoices = pd.read_sql_query(
    "select * from invoice", conn,
    parse_dates=['invoice_date', 'created_at', 'updated_at']
)

# %%
line_items = pd.read_sql_query(
    "select * from line_item", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
tickets = pd.read_sql_query(
    "select * from ticket", conn,
    parse_dates=['assigned_at', 'completed_at', 'created_at', 'updated_at', 'start_time', 'due_date']
)

# %%
users = pd.read_sql_query(
    "select * from user", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
vendor_users = pd.read_sql_query(
    "select * from vendor_user", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
vendor_wells = pd.read_sql_query(
    "select * from vendor_well", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
vendors = pd.read_sql_query(
    "select * from vendor", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
well_locations = pd.read_sql_query(
    "select * from well_location", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
wells = pd.read_sql_query(
    "select * from well", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
work_orders = pd.read_sql_query(
    "select * from work_orders", conn,
    parse_dates=['created_at', 'updated_at', 'estimated_start_date', 'estimated_end_date']
)

# %%
contractor_performance = pd.read_sql_query(
    "select * from contractor_performance", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
contractors.head()
# Out:
#                           contractor_id employee_number  \
# 0  40055e6e-b455-4b5b-a003-e569bb1fa7d8         EMP2238
# 1  052100cd-d521-4a03-8d76-3af432c0841e         EMP1285
# 2  8ca54c1d-d6b6-4711-8851-5719918fa20b         EMP8744
# 3  7cf3a23a-9a46-4da5-9e9a-e1bc0be68e02         EMP0259
# 4  8dc0fb79-4592-4c61-9a7d-6cd2599d0bd2         EMP3565
#
#                               vendor_id                     vendor_manager_id  \
# 0  4851c453-cc2f-41cf-a138-eb4d49b84547  601383f8-270d-4000-af25-d9a0b63194c5
# 1  2155d1b8-bf6c-417b-88cf-531610c1bc0b  9f22ca82-c369-4991-8888-f2a4cf97efb2
# 2  bea4014f-48bc-4afa-a892-b3c0adb2aa33  33abe670-0722-42e2-9632-e7adf7ff933c
# 3  0b4da9c3-c7eb-4440-9931-31f1d9165817  0bff0f68-4579-4103-b1ec-978a174bd382
# 4  0b4da9c3-c7eb-4440-9931-31f1d9165817  8bfe7944-cf67-41ca-82bd-38a09e999bd8
#
#                                 user_id     role    status  \
# 0  29aab2c4-766e-4a14-b4c6-0601a9629abd    admin    active
# 1  b06e257e-3ed6-4e29-b6ec-5be6380d6c2a    admin  inactive
# 2  603f7d71-7218-486a-b581-608e186792f8  manager  inactive
# 3  e3355f1b-6c79-431a-a398-b8767a6aa654     user  inactive
# 4  3a395a23-e44f-420e-bc4f-60ba5c9384f6  manager  inactive
#
#    biometric_enrolled  is_onboarded  is_subcontractor  ...  \
# 0                   1             0                 1  ...
# 1                   1             1                 0  ...
# 2                   0             0                 1  ...
# 3                   1             1                 1  ...
# 4                   0             1                 1  ...
#
#                              address_id  average_rating  years_experience  \
# 0  c904c5e2-6d92-4472-9e0f-40eadfaff1dc            3.10                36
# 1  5c193775-c554-41e1-bf38-f924df340431            3.51                13
# 2  50567c56-d73b-4028-aa15-478e14be0f24            3.65                34
# 3  54c1b692-91cd-457a-8ff6-f9a7dbe140a1            4.51                19
# 4  b93a9797-d201-424e-b3af-770993ea00e6            3.77                11
#
#                     background_check_id  \
# 0  534e646c-95f8-4b4f-9490-b110763fdbb5
# 1  c9e70825-7c76-49b7-870a-7416cf63c422
# 2  7eaf55b1-d124-43b0-bc60-1826be29e8aa
# 3  5def0b1c-e053-45d3-b289-16425438b038
# 4  8ec6a31a-66fb-4df2-958a-8878d313e402
#
#                                  preferred_job_types  \
# 0  ["Psychologist, forensic", "Associate Professor"]
# 1  ["Engineer, electronics", "Programmer, multime...
# 2        ["Technical brewer", "Art gallery manager"]
# 3  ["Planning and development surveyor", "Animal ...
# 4  ["Physicist, medical", "Engineer, building ser...
#
#                            drug_test_id          created_at  \
# 0  fc2175f1-7c50-493e-b0b8-ee6e24b8f81e 2026-01-10 11:51:55
# 1  67461cfc-9d5d-4c01-af6f-b3e0d680b962 2025-06-11 14:58:44
# 2  470fbef0-83c6-4e96-831f-e2ca05a85af8 2025-12-13 17:31:13
# 3  769b428b-f9fa-4cc0-a975-589c40ca0b1e 2026-01-09 14:03:30
# 4  e0d5330b-30c9-4960-98c2-193c025f88fa 2026-03-27 20:33:39
#
#                   updated_at                            created_by  \
# 0 2026-04-07 10:43:07.902530  daf6b1f9-6417-4cc0-a6a1-2c9412cccc3e
# 1 2026-04-07 10:43:07.902626  1deeda68-d0bb-4ea0-9c1b-bfa6306c7143
# 2 2026-04-07 10:43:07.902671  4866b68a-a6eb-4828-9cf9-71360e52d7ba
# 3 2026-04-07 10:43:07.902713  52c14610-7454-4f77-8742-5c2bda6b2fb8
# 4 2026-04-07 10:43:07.902752  11342f3e-41da-4382-aa56-29cce0515b28
#
#                              updated_by
# 0  f8734a1f-fdeb-4dfe-91b0-bb467bb89e09
# 1  aa11c408-2fe2-4b0f-b8df-c10374095b7a
# 2  6233f7cb-95a9-44f2-b8c1-f988fc33c414
# 3  7ace6389-be14-45df-bbe2-1653ae8b2ddb
# 4  1658622c-c1c4-48bb-ae58-df60289b3123
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Vendor Manager KPIs

# %%
test_vendor = vendors.iloc[0]['vendor_id']
test_vendor
# Out:
# '99d37a94-dff8-4a1a-9144-2ed3c16fd181'

# %%
# def contractor_performance_kpi(vendor_id):
#     vendor_contractors = contractors[contractors['vendor_id'] == vendor_id]['contractor_id']
#     df = contractor_performance[contractor_performance['contractor_id'].isin(vendor_contractors)]
#     return df.groupby(['contractor_id'])['rating'].mean().sort_values(ascending=False)

# %%
contractor_performance.head()
# Out:
#                               rating_id                         contractor_id  \
# 0  3278f4bb-0e02-4fb1-81f4-cd099fa23984  61704b62-3d6a-47c1-bb0c-ea9880452eaa
# 1  54722c87-993c-4509-914b-2c29095a9441  892c9a7b-b296-46cb-98b1-8ab2f64bfe19
# 2  0b3e32a4-6f28-4bcf-b976-f84ee7e2a523  052100cd-d521-4a03-8d76-3af432c0841e
# 3  2507a3f2-c6e1-4c31-8e8d-0fb48d1690a7  98a81919-c157-4e93-b862-6be4db3040fa
# 4  ac9ba22d-1d3a-4f5d-b2ac-6f4784a7cae6  283a3547-1546-4b53-a4ac-80d3cb7fa94b
#
#                               ticket_id  rating  \
# 0  8d40ed8e-9f74-4296-9a20-c4385177c72c       5
# 1  c9539fd5-bf5b-4a22-82da-1f8f86b04786       3
# 2  d8e4fbf0-f44e-4aad-9e6c-5a1f8f0444d1       2
# 3  14e1264c-39bc-47a3-8551-3dd4ff1895ae       2
# 4  d300894e-a4f2-475f-8c98-4e68e2bd1e65       1
#
#                                       comments                 created_at  \
# 0  Kind sense source section analysis contain. 2026-04-07 10:43:19.077984
# 1                Word husband product TV able. 2026-04-07 10:43:19.077999
# 2           Room avoid growth outside against. 2026-04-07 10:43:19.078010
# 3                   Agreement able modern eye. 2026-04-07 10:43:19.078025
# 4                      Glass wide baby family. 2026-04-07 10:43:19.078036
#
#                   updated_at                            created_by  \
# 0 2026-04-07 10:43:19.077985  de031b44-eb7e-4131-82f8-f540a5baed76
# 1 2026-04-07 10:43:19.077999  450cc560-5345-4687-898c-2c48a9459702
# 2 2026-04-07 10:43:19.078011  d0b27051-3680-4908-9e4d-661ac4768ee5
# 3 2026-04-07 10:43:19.078025  deacd2bc-f07e-40c8-aba5-968e79ce43aa
# 4 2026-04-07 10:43:19.078037  2a8d93da-2489-425b-9efc-b7ca5c3ad219
#
#                              updated_by
# 0  1e4ccc2a-7ecd-4c1b-8e8b-bea0f577ed9a
# 1  b2a870fa-f977-4c95-ac91-9d41f08abbe5
# 2  166fefb7-073e-4cf2-bdb1-d38d918aa817
# 3  c1835b13-509d-41a8-89cd-34d8f5df4045
# 4  f3236de7-f2ca-4790-a993-3210b2c85698

# %% [markdown]
# ## Vendor Rating

# %%
def vendor_rating(vendor_id):
    vendor_contractors = contractors[contractors['vendor_id'] == vendor_id]['contractor_id']
    df = contractor_performance[contractor_performance['contractor_id'].isin(vendor_contractors)]
    return {'vendor_id': vendor_id, 'average_rating': df['rating'].mean().round(2)}

# %%
vendor_rating(test_vendor)
# Out:
# {'vendor_id': '99d37a94-dff8-4a1a-9144-2ed3c16fd181',
#  'average_rating': np.float64(3.17)}

# %% [markdown]
# ## Number of active contractors

# %%
def active_contractors(vendor_id):
    active_contractors = contractors[(contractors['vendor_id'] == vendor_id) & (contractors['status'] == 'active')]
    return {'vendor_id': vendor_id, 'active_contractors_num': active_contractors.shape[0]}

# %%
active_contractors(test_vendor)
# Out:
# {'vendor_id': '99d37a94-dff8-4a1a-9144-2ed3c16fd181',
#  'active_contractors_num': 9}

# %% [markdown]
# ## Jobs Completed This/Last Month (work in progress)

# %%
tickets.columns
# Out:
# Index(['ticket_id', 'work_order_id', 'description', 'assigned_contractor',
#        'priority', 'status', 'vendor_id', 'start_time', 'due_date',
#        'assigned_at', 'completed_at', 'estimated_duration', 'notes',
#        'contractor_start_location', 'contractor_end_location',
#        'estimated_quantity', 'unit', 'special_requirements', 'anomaly_flag',
#        'anomaly_reason', 'created_at', 'updated_at', 'created_by',
#        'updated_by', 'additional_information'],
#       dtype='str')

# %%
def jobs_completed_current_month(vendor_id):
    now = pd.Timestamp.now()
    start_of_month = now.replace(day=1, hour=0, minute=0, second=0, microsecond=0)

    completed_tickets_this_month = tickets[(tickets['vendor_id'] == vendor_id) & (tickets['status'] == 'completed') & (tickets['completed_at'] >= start_of_month)]
    return completed_tickets_this_month

# %%
jobs_completed_current_month('f6169088-cc06-4c9c-ac65-81bf7614989b')
# Out:
# Empty DataFrame
# Columns: [ticket_id, work_order_id, description, assigned_contractor, priority, status, vendor_id, start_time, due_date, assigned_at, completed_at, estimated_duration, notes, contractor_start_location, contractor_end_location, estimated_quantity, unit, special_requirements, anomaly_flag, anomaly_reason, created_at, updated_at, created_by, updated_by, additional_information]
# Index: []
#
# [0 rows x 25 columns]

# %%
def jobs_completed_last_month(vendor_id):
    now = pd.Timestamp.now()
    start_of_last_month = now.replace(day=1, hour=0, minute=0, second=0, microsecond=0) - pd.offsets.MonthBegin(1)

    completed_tickets_this_month = tickets[(tickets['vendor_id'] == vendor_id) & (tickets['status'] == 'completed') & (tickets['completed_at'] >= start_of_last_month)]
    return completed_tickets_this_month

# %%
jobs_completed_last_month('f6169088-cc06-4c9c-ac65-81bf7614989b')
# Out:
#                                  ticket_id  \
# 1353  d3d017a9-10bc-4ade-ae3c-26d5b7909aab
# 2334  34633d4a-e9e5-4173-997e-a51e3dbe3a1d
# 2711  54b12d27-13ad-4548-98b9-c795541dc4f7
# 3108  861846b7-593f-4657-9177-1db1326aa44e
#
#                              work_order_id  \
# 1353  de21a215-ff92-4b08-b472-2037fce07256
# 2334  de21a215-ff92-4b08-b472-2037fce07256
# 2711  de21a215-ff92-4b08-b472-2037fce07256
# 3108  de21a215-ff92-4b08-b472-2037fce07256
#
#                                             description  \
# 1353  Claim thank admit. Support old fear organizati...
# 2334  Bag two party simply entire remain. Buy later ...
# 2711  Network down standard sign half investment ahe...
# 3108  Consider enjoy woman foreign.\nAffect world wa...
#
#                        assigned_contractor priority     status  \
# 1353  d847636d-5b55-425e-bcf0-f2550f9a516c   urgent  completed
# 2334  575a577b-d77a-41be-b840-9a79436d7ab1   urgent  completed
# 2711  a792f8a9-c8e6-4a3a-b95e-603c672f8002  routine  completed
# 3108  ebd9f396-44bb-4bf0-9dcf-a189ed55e9b8   urgent  completed
#
#                                  vendor_id          start_time  \
# 1353  f6169088-cc06-4c9c-ac65-81bf7614989b 2026-02-06 03:04:48
# 2334  f6169088-cc06-4c9c-ac65-81bf7614989b 2026-02-06 16:27:16
# 2711  f6169088-cc06-4c9c-ac65-81bf7614989b 2026-02-06 11:38:30
# 3108  f6169088-cc06-4c9c-ac65-81bf7614989b 2026-02-05 17:56:52
#
#                 due_date         assigned_at  ... estimated_quantity   unit  \
# 1353 2026-03-07 16:31:49 2026-02-05 04:49:15  ...                 51  hours
# 2334 2026-03-07 16:31:49 2026-02-06 16:00:20  ...                 14  hours
# 2711 2026-03-07 16:31:49 2026-02-05 20:27:06  ...                 67  hours
# 3108 2026-03-07 16:31:49 2026-02-04 16:34:56  ...                 62  hours
#
#                                 special_requirements anomaly_flag  \
# 1353                           Grow cup inside data.            0
# 2334        Piece later may pressure case growth he.            1
# 2711       Institution serve save ahead age without.            1
# 3108  Matter measure street able decision race five.            0
#
#                        anomaly_reason          created_at  \
# 1353                              NaN 2026-02-03 09:41:17
# 2334       Guess pick inside require. 2026-02-02 22:17:22
# 2711                              NaN 2026-02-01 16:59:25
# 3108  Condition science forward hand. 2026-02-01 09:29:47
#
#                      updated_at                            created_by  \
# 1353 2026-04-07 10:43:11.129309  0df1d506-f548-4c3f-ab25-c7fcaf2a42da
# 2334 2026-04-07 10:43:13.309502  fc5f420d-e4a0-43de-a3f3-0735c49f2d44
# 2711 2026-04-07 10:43:14.126880  2414db82-fe11-4d65-96e5-4231ae93884c
# 3108 2026-04-07 10:43:15.012400  9f22ca82-c369-4991-8888-f2a4cf97efb2
#
#                                 updated_by  \
# 1353  69d90a14-c138-42a4-a286-69770e2ca565
# 2334  bb39d29a-3850-4cff-9262-8fa17a75d47c
# 2711  2582c1bf-7c4e-43db-a220-ca55dd8fddd6
# 3108  a1ac6e5a-561a-42b8-a7fc-774adc7068e7
#
#                                  additional_information
# 1353  [{"name": "Kelli Carr", "residency": "Unit 201...
# 2334  [{"name": "Linda Cardenas", "residency": "289 ...
# 2711  [{"name": "Evan Wilson", "residency": "98145 Y...
# 3108  [{"name": "Tricia Romero", "residency": "929 H...
#
# [4 rows x 25 columns]

# %% [markdown]
# ## On Time Completion

# %%
# def contractor_on_time_delivery(vendor_id, start_time, end_time=datetime.now()):
#     start_time = pd.to_datetime(start_time)
#     end_time = pd.to_datetime(end_time)
#     df = tickets[(tickets['completed_at'].between(start_time, end_time)) & (tickets['vendor_id'] == vendor_id)]
#     completed_late = df['completed_at'] > df['due_date']
#     overdue = (df['completed_at'].isna()) & (df['due_date'] < end_time)
#     # print(df.head())
#     df['on_time'] = ~(completed_late | overdue)

#     ticket_kpi = df.groupby('assigned_contractor').agg({
#         'on_time': 'mean',
#         'ticket_id': 'count'
#     })
#     ticket_kpi.rename(columns={'ticket_id': 'ticket_count'}, inplace=True)
#     ticket_kpi['on_time'] = (ticket_kpi['on_time'] * 100).round(2)
#     contractor_info = contractors[contractors['contractor_id'].isin(df['assigned_contractor'])]

#     vendor_kpi = pd.merge(contractor_info, ticket_kpi, left_on='contractor_id', right_on='assigned_contractor').sort_values(by='on_time', ascending=False)
#     vendor_kpi = vendor_kpi[['employee_number', 'on_time', 'ticket_count']]
#     return vendor_kpi

# %%
def contractor_on_time_delivery(vendor_id, start_time, end_time=None):
    if end_time is None:
        end_time = datetime.now()

    start_time = pd.to_datetime(start_time)
    end_time = pd.to_datetime(end_time)

    df = tickets[
        (tickets["vendor_id"] == vendor_id) &
        (tickets["due_date"].between(start_time, end_time, inclusive="both"))
    ].copy()

    df["on_time"] = (
        df["completed_at"].notna() &
        (df["completed_at"] <= df["due_date"])
    )

    ticket_kpi = (
        df.groupby("assigned_contractor", as_index=False)
          .agg(
              on_time_count=("on_time", "sum"),
              ticket_count=("ticket_id", "count")
          )
    )

    ticket_kpi["on_time_pct"] = (
        ticket_kpi["on_time_count"] / ticket_kpi["ticket_count"] * 100
    ).round(2)

    contractor_info = contractors[
        contractors["contractor_id"].isin(ticket_kpi["assigned_contractor"])
    ][["contractor_id", "employee_number"]]

    return (
        contractor_info.merge(
            ticket_kpi,
            left_on="contractor_id",
            right_on="assigned_contractor",
            how="inner"
        )
        .sort_values(by="on_time_pct", ascending=False)
        [["employee_number", "on_time_count", "ticket_count", "on_time_pct"]]
    )

# %%
oct25 = datetime.strptime('2025-09-30', '%Y-%m-%d').date()

# %%
contractor_on_time_delivery(test_vendor, oct25)
# Out:
#    employee_number  on_time_count  ticket_count  on_time_pct
# 5          EMP9129              2             8        25.00
# 9          EMP1519              3            13        23.08
# 11         EMP5526              1             5        20.00
# 7          EMP2827              2            14        14.29
# 3          EMP5929              1             9        11.11
# 6          EMP0113              1            10        10.00
# 4          EMP8417              1            12         8.33
# 1          EMP6857              1            17         5.88
# 8          EMP7987              1            19         5.26
# 0          EMP4222              0             9         0.00
# 2          EMP6960              0            10         0.00
# 10         EMP2506              0            11         0.00
# 12         EMP0901              0             8         0.00
# 13         EMP4337              0             8         0.00
# 14         EMP8924              0            12         0.00
# 15         EMP5363              0             9         0.00
# 16         EMP0891              0            11         0.00

# %%
test_vendor
# Out:
# '99d37a94-dff8-4a1a-9144-2ed3c16fd181'
