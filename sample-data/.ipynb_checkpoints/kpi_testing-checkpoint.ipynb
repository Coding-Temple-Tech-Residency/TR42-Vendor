# %%
import pandas as pd
import sqlite3
from datetime import datetime, timedelta

# %%
conn = sqlite3.connect("./my_database.db")

addresses = pd.read_sql_query(
    "select * from address", conn,
    parse_dates=['created_at', 'updated_at']
)

contractors = pd.read_sql_query(
    "select * from contractors", conn,
    parse_dates=['created_at', 'updated_at']
)

invoices = pd.read_sql_query(
    "select * from invoice", conn,
    parse_dates=['invoice_date', 'created_at', 'updated_at']
)

line_items = pd.read_sql_query(
    "select * from line_item", conn,
    parse_dates=['created_at', 'updated_at']
)

tickets = pd.read_sql_query(
    "select * from ticket", conn,
    parse_dates=['assigned_at', 'completed_at', 'created_at', 'updated_at', 'start_time', 'due_date']
)

users = pd.read_sql_query(
    "select * from user", conn,
    parse_dates=['created_at', 'updated_at']
)

vendor_users = pd.read_sql_query(
    "select * from vendor_user", conn,
    parse_dates=['created_at', 'updated_at']
)

vendor_wells = pd.read_sql_query(
    "select * from vendor_well", conn,
    parse_dates=['created_at', 'updated_at']
)

vendors = pd.read_sql_query(
    "select * from vendor", conn,
    parse_dates=['created_at', 'updated_at']
)

well_locations = pd.read_sql_query(
    "select * from well_location", conn,
    parse_dates=['created_at', 'updated_at']
)

wells = pd.read_sql_query(
    "select * from well", conn,
    parse_dates=['created_at', 'updated_at']
)

work_orders = pd.read_sql_query(
    "select * from work_orders", conn,
    parse_dates=['created_at', 'updated_at']
)

# %%
# vendor_tickets = pd.merge(vendors, tickets, on='vendor_id', suffixes=['_vendor', '_ticket'])

# %%
# vendor_tickets.head()

# %%
tickets.head()
# Out:
#                               ticket_id                         work_order_id  \
# 0  0fda38ab-df73-4bec-a6ba-5bd7ae42c05e  959a6545-78d6-44c4-aa83-38d3481da59c
# 1  669fd84c-7326-48aa-9840-531caaa0fccb  ba77c8fd-7d4b-41a2-8a18-c7c2a65b6057
# 2  93005053-eb08-4f27-826f-3036875c8ed2  f8f4f0bc-b4c4-4212-8acf-139fda999ffc
# 3  07018840-e601-43e4-aa04-cabd25ae2854  9f500f72-0857-4e98-a157-8599d6066b01
# 4  a2e0ff24-1e45-47f9-8299-26f47469b4fb  3076f7f3-4d4c-46df-afeb-fa09b6732c58
#
#                                          description  \
# 0  Assume matter sea place. Offer dark themselves...
# 1  Interesting about call three Democrat thus act...
# 2  Surface decide floor fall. See teacher parent ...
# 3  Fight each style establish. Use happen tax lan...
# 4  Whatever experience heavy administration respo...
#
#                     assigned_contractor   priority     status  \
# 0  36fae403-9c04-4d5a-a2d9-168337a91692    routine   assigned
# 1  046f7742-f7ad-40f9-95b4-c56dfa512502    routine  completed
# 2  0a1a5eb5-56e4-41ad-9b09-8be4257ae9fc    routine  completed
# 3  bd3b62a2-a9d0-476e-a534-72c7a4f6f3df  emergency  completed
# 4  e3fab306-b41c-4a1c-b098-6849db5bcd31    routine   assigned
#
#                               vendor_id          start_time  \
# 0  161808d6-27cf-4a7d-8594-44b883f3eecb 2025-09-12 20:26:20
# 1  d3b84b56-3e29-498d-a041-ab9a641ac116 2026-01-27 21:44:46
# 2  625b4d57-94d7-446c-b9f6-514d31300c55 2025-07-17 22:07:07
# 3  ea07d039-7479-4333-8e52-43283839a96e 2025-12-13 21:37:28
# 4  d3b84b56-3e29-498d-a041-ab9a641ac116 2026-02-03 23:10:29
#
#              due_date         assigned_at  ... estimated_quantity   unit  \
# 0 2025-09-20 15:53:43 2025-09-12 15:02:52  ...                 77  hours
# 1 2026-02-02 15:21:11 2026-01-27 01:56:03  ...                 18  hours
# 2 2025-07-23 18:29:55 2025-07-15 23:23:52  ...                 25  hours
# 3 2025-12-17 21:41:17 2025-12-13 06:25:12  ...                 81  hours
# 4 2026-02-07 07:38:49 2026-02-03 15:47:12  ...                  1  hours
#
#                                 special_requirements anomaly_flag  \
# 0     Herself yard mean federal speech brother even.            1
# 1   Practice turn this stage investment glass child.            0
# 2              Reach option race eat huge challenge.            0
# 3  Offer level total design star evidence represent.            1
# 4                              Husband agree animal.            1
#
#                                       anomaly_reason          created_at  \
# 0  Movement impact remain production partner anyt... 2025-09-10 22:45:42
# 1                                 Side before avoid. 2026-01-26 17:37:23
# 2        Positive girl newspaper myself at official. 2025-07-15 08:04:48
# 3           Turn life we continue go phone painting. 2025-12-11 11:34:33
# 4                  Whose young theory law use crime. 2026-02-01 21:41:57
#
#                   updated_at                            created_by  \
# 0 2026-04-04 17:46:51.972179  5aadcc13-4141-4c70-ba13-22d0920f4fd6
# 1 2026-04-04 17:46:51.975638  61194c69-fe7c-4de4-9365-29542d492692
# 2 2026-04-04 17:46:51.978804  75934138-785b-404d-ac86-2a7b0008d4e7
# 3 2026-04-04 17:46:51.981715  538f879a-8711-4db5-9232-cd0bb95845bd
# 4 2026-04-04 17:46:51.985285  3aad03fb-39ca-46ee-b7db-001000d73bcf
#
#                              updated_by  \
# 0  fed834d0-852a-4e1a-ba40-2aa9fe662d1d
# 1  a98e6027-ca61-4910-8ea5-d403d26cee81
# 2  8e80264e-4912-4c8c-bed5-d3263ac5ddfc
# 3  c4bb1014-9da4-422e-a4f1-6dc51ef032e4
# 4  f22c88ab-3300-4a32-bd3f-9ca0fdeb83ea
#
#                               additional_information
# 0  [{"name": "Veronica Jones", "residency": "061 ...
# 1  [{"name": "Steven Thompson", "residency": "051...
# 2  [{"name": "Joseph Ruiz", "residency": "4977 Co...
# 3  [{"name": "Brittany Lynn", "residency": "5501 ...
# 4  [{"name": "Elizabeth Knox", "residency": "2238...
#
# [5 rows x 25 columns]

# %%
# tickets['quarter'] = tickets['created_at'].dt.quarter

# %%
# completed_tickets = tickets[tickets['status'] == 'completed']
# completed_tickets.shape

# %%
# completed_tickets['completion_time'] = completed_tickets['completed_at'] - completed_tickets['assigned_at']

# %%
# completed_tickets['response_time'] = completed_tickets['start_time'] - completed_tickets['assigned_at']

# %%
# completed_tickets.groupby('quarter')['completion_time'].mean()

# %%
# completed_tickets.groupby('quarter')['response_time'].mean()

# %%
# completed_tickets.groupby('quarter')['ticket_id'].count()

# %%
# tickets['month'] = tickets['created_at'].dt.month_name()

# %%
# tickets[tickets['quarter'] == 4].month.value_counts()

# %%
# completed_tickets.groupby('vendor_id')['completion_time'].mean().sort_values(ascending=False)

# %%
# completed_tickets.groupby('vendor_id')['response_time'].mean().sort_values(ascending=False)

# %%
# completed_tickets.groupby('vendor_id')['ticket_id'].count()

# %%
# vendor_kpis = completed_tickets.groupby('vendor_id').agg({
#     "completion_time": 'mean',
#     "response_time": 'mean',
#     "ticket_id": 'count'
# })
# vendor_kpis

# %%
# vendor_info = vendors[['vendor_id', 'company_name']]

# %%
# vendor_info

# %%
# pd.merge(vendor_info, vendor_kpis, on='vendor_id')

# %% [markdown]
# # Vendor/Client Admin KPIs

# %% [markdown]
# ## On Time Delivery %
# percentage of tickets completed on time within a specified range

# %%
cols = ['ticket_id', 'created_at', 'assigned_at', 'start_time', 'completed_at', 'due_date']

# %%
def overall_vendor_on_time_delivery(start_time, end_time=datetime.now()):
    df = tickets[tickets['created_at'].between(start_time, end_time)]
    completed_late = df['completed_at'] > df['due_date']
    overdue = (df['completed_at'].isna()) & (df['due_date'] < end_time)

    df['on_time'] = ~(completed_late | overdue)

    ticket_kpi = df.groupby('vendor_id').agg({
        'on_time': 'mean',
        'ticket_id': 'count'
    })
    ticket_kpi['on_time'] = (ticket_kpi['on_time'] * 100).round(2)
    vendor_info = vendors[['vendor_id', 'company_name']]

    vendor_kpi = pd.merge(vendor_info, ticket_kpi, on='vendor_id')
    return vendor_kpi

# %%
# three_months = pd.Timestamp.now() - pd.DateOffset(months=3)
# tickets_created_3_months = tickets[tickets['created_at'] >= three_months].reset_index()

# completed_late = tickets_created_3_months['completed_at'] > tickets_created_3_months['due_date']
# overdue = (tickets_created_3_months['completed_at'].isna()) & (tickets_created_3_months['due_date'] < pd.Timestamp.now())

# tickets_created_3_months['on_time'] = ~(completed_late | overdue)

# # tickets_created_3_months[cols].head(10)

# tickets_created_3_months['on_time'].value_counts(normalize=True)

# # tickets_created_3_months[tickets_created_3_months['on_time'] == True][cols]

# tickets_created_3_months.groupby('vendor_id')['on_time'].mean().round(4) * 100

# %%
nov_2025 = datetime.strptime('2025-11-01', '%Y-%m-%d')
feb_2026 = datetime.strptime('2026-03-01', '%Y-%m-%d')

# %%
overall_vendor_on_time_delivery(nov_2025, feb_2026)
# Out:
#                               vendor_id                   company_name  \
# 0  d3b84b56-3e29-498d-a041-ab9a641ac116  Baker, Williams and Velasquez
# 1  ea07d039-7479-4333-8e52-43283839a96e                       Rich Inc
# 2  625b4d57-94d7-446c-b9f6-514d31300c55                Gallagher-Miles
# 3  ab40b99e-9d73-49fb-aca7-6f99c7eb0eda                  Cook-Chambers
# 4  bb4e60aa-06fc-4a34-beda-9ce1c1347d38       Romero, Cobb and Burnett
# 5  a945cafa-5b8d-4693-990d-ca0bfa7eb8cb                       Chan PLC
# 6  161808d6-27cf-4a7d-8594-44b883f3eecb                Hoover-Peterson
# 7  863d66df-459b-4ed5-bc01-de39738ffba9                      Lopez Ltd
# 8  73a61173-f9e5-46f4-85a9-c15c7db341f2                    Hill-Potter
# 9  6edc1183-94c7-4949-8533-f7085d526e05                     Booker LLC
#
#    on_time  ticket_id
# 0    43.42        152
# 1    31.25        128
# 2    31.35        185
# 3    38.01        171
# 4    39.29        168
# 5    36.69        169
# 6    44.39        187
# 7    35.75        207
# 8    43.01         93
# 9    37.43        179

# %%
overall_vendor_on_time_delivery(nov_2025)
# Out:
#                               vendor_id                   company_name  \
# 0  d3b84b56-3e29-498d-a041-ab9a641ac116  Baker, Williams and Velasquez
# 1  ea07d039-7479-4333-8e52-43283839a96e                       Rich Inc
# 2  625b4d57-94d7-446c-b9f6-514d31300c55                Gallagher-Miles
# 3  ab40b99e-9d73-49fb-aca7-6f99c7eb0eda                  Cook-Chambers
# 4  bb4e60aa-06fc-4a34-beda-9ce1c1347d38       Romero, Cobb and Burnett
# 5  a945cafa-5b8d-4693-990d-ca0bfa7eb8cb                       Chan PLC
# 6  161808d6-27cf-4a7d-8594-44b883f3eecb                Hoover-Peterson
# 7  863d66df-459b-4ed5-bc01-de39738ffba9                      Lopez Ltd
# 8  73a61173-f9e5-46f4-85a9-c15c7db341f2                    Hill-Potter
# 9  6edc1183-94c7-4949-8533-f7085d526e05                     Booker LLC
#
#    on_time  ticket_id
# 0    40.10        197
# 1    33.74        163
# 2    32.23        242
# 3    40.89        225
# 4    36.57        216
# 5    33.17        205
# 6    42.13        235
# 7    36.84        285
# 8    42.06        126
# 9    38.98        236

# %%
(tickets['completed_at'].dt.normalize() == datetime.today().date()).sum()
# Out:
# np.int64(0)

# %%
tickets['completed_at'].dt.normalize().value_counts()
# Out:
# completed_at
# 2025-08-03    12
# 2026-03-15    11
# 2025-11-26    10
# 2026-01-03    10
# 2025-05-01    10
#               ..
# 2025-10-23     1
# 2025-04-09     1
# 2025-08-22     1
# 2025-06-14     1
# 2025-05-07     1
# Name: count, Length: 365, dtype: int64

# %% [markdown]
# ## Average Duration of Ticket

# %%
df = tickets[~tickets['completed_at'].isna()]
df.shape
# Out:
# (1706, 25)

# %%
df['completion_time'] = df['completed_at'] - df['assigned_at']

# %%
df['completion_time'].mean()
# Out:
# Timedelta('2 days 12:04:40.573856')

# %%
def overall_vendor_ticket_duration(start_time, end_time=datetime.now()):
    df = tickets[tickets['completed_at'].between(start_time, end_time)] # all completed tickets in time range
    df['completion_time'] = df['completed_at'] - df['assigned_at']

    kpi = df.groupby('vendor_id')['completion_time'].mean().sort_values(ascending=True)
    vendor_info = vendors[['vendor_id', 'company_name']]

    vendor_kpi = pd.merge(vendor_info, kpi, on='vendor_id')

    return vendor_kpi

# %%
overall_vendor_ticket_duration(nov_2025, feb_2026)
# Out:
#                               vendor_id                   company_name  \
# 0  d3b84b56-3e29-498d-a041-ab9a641ac116  Baker, Williams and Velasquez
# 1  ea07d039-7479-4333-8e52-43283839a96e                       Rich Inc
# 2  625b4d57-94d7-446c-b9f6-514d31300c55                Gallagher-Miles
# 3  ab40b99e-9d73-49fb-aca7-6f99c7eb0eda                  Cook-Chambers
# 4  bb4e60aa-06fc-4a34-beda-9ce1c1347d38       Romero, Cobb and Burnett
# 5  a945cafa-5b8d-4693-990d-ca0bfa7eb8cb                       Chan PLC
# 6  161808d6-27cf-4a7d-8594-44b883f3eecb                Hoover-Peterson
# 7  863d66df-459b-4ed5-bc01-de39738ffba9                      Lopez Ltd
# 8  73a61173-f9e5-46f4-85a9-c15c7db341f2                    Hill-Potter
# 9  6edc1183-94c7-4949-8533-f7085d526e05                     Booker LLC
#
#          completion_time
# 0 2 days 12:05:52.813559
# 1 2 days 13:54:29.128205
# 2 2 days 11:36:36.303571
# 3 2 days 09:55:07.833333
# 4 2 days 10:49:44.754385
# 5 2 days 09:08:06.280701
# 6 2 days 12:27:54.450704
# 7 2 days 11:37:14.562500
# 8 2 days 18:00:59.894736
# 9 2 days 12:44:19.706896

# %%
overall_vendor_ticket_duration(nov_2025)
# Out:
#                               vendor_id                   company_name  \
# 0  d3b84b56-3e29-498d-a041-ab9a641ac116  Baker, Williams and Velasquez
# 1  ea07d039-7479-4333-8e52-43283839a96e                       Rich Inc
# 2  625b4d57-94d7-446c-b9f6-514d31300c55                Gallagher-Miles
# 3  ab40b99e-9d73-49fb-aca7-6f99c7eb0eda                  Cook-Chambers
# 4  bb4e60aa-06fc-4a34-beda-9ce1c1347d38       Romero, Cobb and Burnett
# 5  a945cafa-5b8d-4693-990d-ca0bfa7eb8cb                       Chan PLC
# 6  161808d6-27cf-4a7d-8594-44b883f3eecb                Hoover-Peterson
# 7  863d66df-459b-4ed5-bc01-de39738ffba9                      Lopez Ltd
# 8  73a61173-f9e5-46f4-85a9-c15c7db341f2                    Hill-Potter
# 9  6edc1183-94c7-4949-8533-f7085d526e05                     Booker LLC
#
#          completion_time
# 0 2 days 13:38:35.380281
# 1 2 days 16:09:05.340000
# 2 2 days 13:32:47.285714
# 3 2 days 13:10:55.250000
# 4 2 days 10:20:03.027027
# 5 2 days 07:31:27.557142
# 6        2 days 13:02:34
# 7 2 days 12:18:26.817204
# 8 2 days 17:47:57.500000
# 9 2 days 11:31:53.409638

# %% [markdown]
# ## Currently Open Tickets

# %%
def overall_vendor_open_tickets():
    open_tickets = tickets[tickets['status'] != 'completed']
    kpi = pd.pivot_table(open_tickets, index='vendor_id', columns='status', values='ticket_id', aggfunc='count').reset_index()
    kpi['total'] = kpi['assigned'] + kpi['in progress']
    vendor_info = vendors[['vendor_id', 'company_name']]

    vendor_kpi = pd.merge(vendor_info, kpi, on='vendor_id')
    return vendor_kpi

# %%
overall_vendor_open_tickets()
# Out:
#                               vendor_id                   company_name  \
# 0  d3b84b56-3e29-498d-a041-ab9a641ac116  Baker, Williams and Velasquez
# 1  ea07d039-7479-4333-8e52-43283839a96e                       Rich Inc
# 2  625b4d57-94d7-446c-b9f6-514d31300c55                Gallagher-Miles
# 3  ab40b99e-9d73-49fb-aca7-6f99c7eb0eda                  Cook-Chambers
# 4  bb4e60aa-06fc-4a34-beda-9ce1c1347d38       Romero, Cobb and Burnett
# 5  a945cafa-5b8d-4693-990d-ca0bfa7eb8cb                       Chan PLC
# 6  161808d6-27cf-4a7d-8594-44b883f3eecb                Hoover-Peterson
# 7  863d66df-459b-4ed5-bc01-de39738ffba9                      Lopez Ltd
# 8  73a61173-f9e5-46f4-85a9-c15c7db341f2                    Hill-Potter
# 9  6edc1183-94c7-4949-8533-f7085d526e05                     Booker LLC
#
#    assigned  in progress  total
# 0       155          147    302
# 1       132          124    256
# 2       214          208    422
# 3       185          206    391
# 4       176          151    327
# 5       145          143    288
# 6       151          190    341
# 7       213          204    417
# 8        86           89    175
# 9       179          196    375
